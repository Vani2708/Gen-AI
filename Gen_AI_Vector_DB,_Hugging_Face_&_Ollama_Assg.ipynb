# %% [markdown]
# # **Vector DB, Hugging Face & Ollama Questions:**

# %% [markdown]
# **1. What is a Vector Database (VectorDB) and how is it different from traditional databases?**
#
# Ans: A Vector Database (VectorDB) is a specialized database designed to store, index, and search vector embeddings generated by machine learning models. These vectors represent data such as text, images, audio, or video in numerical form, allowing similarity comparisons using mathematical distance metrics like cosine similarity, Euclidean distance, or dot product.
#
# Vector databases are widely used in Artificial Intelligence (AI) applications such as semantic search, recommendation systems, and Retrieval-Augmented Generation (RAG).
#
# Key Features of Vector Databases
#
# Store high-dimensional vector embeddings.
#
# Perform similarity search efficiently.
#
# Use indexing techniques like HNSW (Hierarchical Navigable Small World) or FAISS indexing.
#
# Designed for AI/ML workflows.
#
# **Difference Between Vector Databases and Traditional Databases (Short Answer):**
#
# A **Vector Database** stores data in the form of **vector embeddings**, which are numerical representations generated by AI or machine learning models. It is designed to perform **similarity searches**, meaning it finds results that are semantically or contextually similar to a query. This makes vector databases useful for applications like semantic search, recommendation systems, and AI chatbots.
#
# In contrast, **Traditional Databases** store **structured data in tables with rows and columns** and retrieve information using exact queries or conditions, usually through SQL. They are commonly used for applications such as banking systems, inventory management, and record keeping.
#
# In simple terms, **vector databases focus on similarity-based search for AI applications**, while **traditional databases focus on exact data retrieval for structured information**.

# %% [markdown]
# **2. Explain the various types of VectorDBs available and describe their suitability for different use cases.**
#
# Ans: Vector databases can be categorized based on architecture and functionality.
#
# 1. **Open Source Vector Databases**
#
# Examples:
#
# ChromaDB
#
# FAISS
#
# Milvus
#
# **Characteristics**
#
# Free and customizable
#
# Suitable for research and development
#
# Can run locally
#
# **Use Cases**
#
# AI prototypes
#
# Academic research
#
# Local RAG systems
#
# 2. **Managed Vector Databases (Cloud Based)**
#
# Examples:
#
# Pinecone
#
# Weaviate Cloud
#
# Qdrant Cloud
#
# **Characteristics**
#
# Fully managed infrastructure
#
# Automatic scaling
#
# High availability
#
# **Use Cases**
#
# Production AI systems
#
# Large scale semantic search
#
# Enterprise applications
#
# 3. **Hybrid Databases (Vector + Traditional)**
#
# Examples:
#
# PostgreSQL with pgvector
#
# ElasticSearch with vector search
#
# **Characteristics**
#
# Combine relational queries with vector similarity search
#
# Store metadata and embeddings together
#
# **Use Cases**
#
# Recommendation systems
#
# Product search engines
#
# E-commerce AI

# %% [markdown]
# **3: Why is Chroma DB considered important in the context of AI/ML projects? Describe its key features.**
#
# Answer:
#
# Chroma DB is an open-source vector database designed specifically for AI and machine learning applications, especially LLM-based applications like chatbots and semantic search.
#
# It allows developers to store embeddings and retrieve them efficiently.
#
# **Importance in AI/ML**
#
# Chroma DB is widely used in:
#
# Retrieval Augmented Generation (RAG)
#
# AI chatbots
#
# Document search systems
#
# Knowledge bases for LLMs
#
# It integrates easily with frameworks such as:
#
# LangChain
#
# LlamaIndex
#
# Hugging Face models
#
# **Key Features**
#
# 1. Efficient Vector Storage:
#
# Stores embeddings generated by ML models.
#
# 2. Fast Similarity Search:
#
# Finds the most relevant information quickly.
#
# 3. Easy Integration:
#
# Works with Python, LangChain, and LLM frameworks.
#
# 4. Local Deployment:
#
# Can run locally without cloud services.
#
# 5. Metadata Support
#
# Allows storing extra information with vectors.
#
# 6. Persistence:
#
# Saves data locally for reuse.
#
# **Advantages**
#
# Lightweight
#
# Open source
#
# Easy to set up
#
# Ideal for RAG pipelines
#
# Thus, Chroma DB plays a crucial role in building AI knowledge retrieval systems.

# %% [markdown]
# **4: What are the benefits of using Hugging Face Hub for generative AI tasks?**
#
# Answer:
#  Hugging Face Hub is a platform that hosts thousands of pre-trained machine learning models, datasets, and tools for Natural Language Processing (NLP), computer vision, and generative AI.
#
# It has become a central ecosystem for modern AI development.
#
# **Benefits**
# 1. **Access to Thousands of Pre-trained Models**:
#
# Developers can easily use models for tasks such as:
#
# Text generation
#
# Question answering
#
# Translation
#
# Summarization
#
# Examples include models like GPT, BERT, and T5.
#
# 2. **Easy Integration with Python**
#
# Using the Transformers library, models can be loaded with just a few lines of code.
#
# Example:

# %%
from transformers import pipeline

generator = pipeline("text-generation", model="gpt2")
print(generator("Artificial intelligence is"))
# Out:
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# config.json:   0%|          | 0.00/665 [00:00<?, ?B/s]
# ...
# WARNING:huggingface_hub.utils._http:Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# model.safetensors:   0%|          | 0.00/548M [00:00<?, ?B/s]
# Loading weights:   0%|          | 0/148 [00:00<?, ?it/s]
# GPT2LMHeadModel LOAD REPORT from: gpt2
# Key                  | Status     |  |
# ...

# %% [markdown]
# **3. Open Source Ecosystem**:
#
# Researchers and developers share:
#
# Models
#
# Datasets
#
# Training scripts
#
# This encourages collaboration.
#
# 4. **Fine-Tuning Support:**
#
# Users can modify pre-trained models using their own datasets to improve performance.
#
# 5. **Version Control:**
#
# Models are versioned similar to GitHub repositories, making updates and collaboration easier.
#
# 6. **Easy Deployment:**
#
# Models can be deployed using:
#
# APIs
#
# Hugging Face Spaces
#
# Local inference

# %% [markdown]
# 5. **Describe the process and advantages of navigating and using pre-trained models from the Hugging Face Hub.**
#
# Answer:
# Process of Using Pre-trained Models
# **Step 1: Visit Hugging Face Hub**
#
# Users can browse models on the platform and filter them based on task such as:
#
# Text generation
#
# Image classification
#
# Translation
#
# **Step 2: Select a Model**
#
# Each model page contains:
#
# Model description
#
# Example code
#
# Performance benchmarks
#
# License information
#
# **Step 3: Install Required Libraries**

# %%
pip install transformers
pip install torch
# Out:
#   File "/tmp/ipykernel_586/3976366845.py", line 1
#     pip install transformers
#         ^
# SyntaxError: invalid syntax

# %% [markdown]
# **Step 4: Load the Model in Python**

# %%
from transformers import pipeline

classifier = pipeline("sentiment-analysis")
result = classifier("I love AI technology!")
print(result)
# Out:
# No model was supplied, defaulted to distilbert/distilbert-base-uncased-finetuned-sst-2-english and revision 714eb0f.
# Using a pipeline without specifying a model name and revision in production is not recommended.
# config.json:   0%|          | 0.00/629 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/268M [00:00<?, ?B/s]
# Loading weights:   0%|          | 0/104 [00:00<?, ?it/s]
# tokenizer_config.json:   0%|          | 0.00/48.0 [00:00<?, ?B/s]
# vocab.txt: 0.00B [00:00, ?B/s]
# [{'label': 'POSITIVE', 'score': 0.9997912049293518}]

# %% [markdown]
# **Step 5: Run Inference**
#
# The model processes input data and produces predictions or generated text.
#
# **Advantages**
#
# Saves development time
#
# Eliminates need to train models from scratch
#
# Provides high-quality state-of-the-art models
#
# Easy experimentation with different models
#
# Strong community support

# %% [markdown]
# 6: **Install and set up Chroma DB, and insert sample vector data for semantic search.**
#
# Answer:
#
# Installation:
# pip install chromadb sentence-transformers

# %%
import chromadb
from sentence_transformers import SentenceTransformer

# Initialize embedding model
model = SentenceTransformer('all-MiniLM-L6-v2')

# Create Chroma client
client = chromadb.Client()

# Create collection
collection = client.create_collection(name="documents")

# Sample data
docs = [
    "Artificial Intelligence is transforming technology",
    "Machine learning improves data analysis",
    "Vector databases help semantic search",
    "Deep learning powers modern AI"
]

# Convert to embeddings
embeddings = model.encode(docs).tolist()

# Add data to ChromaDB
collection.add(
    documents=docs,
    embeddings=embeddings,
    ids=["1","2","3","4"]
)

# Query
query = "How AI helps search"
query_embedding = model.encode([query]).tolist()

results = collection.query(
    query_embeddings=query_embedding,
    n_results=2
)

print(results)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /tmp/ipykernel_586/1437475492.py in <cell line: 0>()
# ----> 1 import chromadb
#       2 from sentence_transformers import SentenceTransformer
#       3
#       4 # Initialize embedding model
#       5 model = SentenceTransformer('all-MiniLM-L6-v2')
#
# ModuleNotFoundError: No module named 'chromadb'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %% [markdown]
# **7. Demonstrate how to download and fine-tune a Hugging Face model for a text generation task.**
#
# Answer:
#
# Install Libraries:
# pip install transformers datasets torch

# %%
from transformers import AutoTokenizer, AutoModelForCausalLM, Trainer, TrainingArguments
from datasets import load_dataset

model_name = "gpt2"

tokenizer = AutoTokenizer.from_pretrained(model_name)
model = AutoModelForCausalLM.from_pretrained(model_name)

dataset = load_dataset("wikitext", "wikitext-2-raw-v1")

def tokenize_function(examples):
    return tokenizer(examples["text"], truncation=True)

tokenized_datasets = dataset.map(tokenize_function, batched=True)

training_args = TrainingArguments(
    output_dir="./results",
    per_device_train_batch_size=2,
    num_train_epochs=1
)

trainer = Trainer(
    model=model,
    args=training_args,
    train_dataset=tokenized_datasets["train"]
)

trainer.train()
# Out:
# Loading weights:   0%|          | 0/148 [00:00<?, ?it/s]
# GPT2LMHeadModel LOAD REPORT from: gpt2
# Key                  | Status     |  |
# ---------------------+------------+--+-
# h.{0...11}.attn.bias | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# README.md: 0.00B [00:00, ?B/s]
# wikitext-2-raw-v1/test-00000-of-00001.pa(…):   0%|          | 0.00/733k [00:00<?, ?B/s]
# wikitext-2-raw-v1/train-00000-of-00001.p(…):   0%|          | 0.00/6.36M [00:00<?, ?B/s]
# wikitext-2-raw-v1/validation-00000-of-00(…):   0%|          | 0.00/657k [00:00<?, ?B/s]
# ...
# Map:   0%|          | 0/3760 [00:00<?, ? examples/s]
# /usr/local/lib/python3.12/dist-packages/torch/utils/data/dataloader.py:775: UserWarning: 'pin_memory' argument is set as true but no accelerator is found, then device pinned memory won't be used.
#   super().__init__(loader)
# ...

# %% [markdown]
# **8: Create a custom LLM using Ollama and Llama2, and run it locally for basic text prompts.**
#
# Answer:
#
# Install Ollama
#
# Download from the official site and install.
#
# Pull Model
# ollama pull llama2

# %%
import requests

url = "http://localhost:11434/api/generate"

data = {
    "model": "llama2",
    "prompt": "Explain artificial intelligence in simple terms.",
    "stream": False
}

response = requests.post(url, json=data)
print(response.json()["response"])
# Out:
# ---------------------------------------------------------------------------
# ConnectionRefusedError                    Traceback (most recent call last)
# /usr/local/lib/python3.12/dist-packages/urllib3/connection.py in _new_conn(self)
#     197         try:
# --> 198             sock = connection.create_connection(
#     199                 (self._dns_host, self.port),
#
# /usr/local/lib/python3.12/dist-packages/urllib3/util/connection.py in create_connection(address, timeout, source_address, socket_options)
#      84         try:
# ---> 85             raise err
#      86         finally:
#
# /usr/local/lib/python3.12/dist-packages/urllib3/util/connection.py in create_connection(address, timeout, source_address, socket_options)
#      72                 sock.bind(source_address)
# ---> 73             sock.connect(sa)
#      74             # Break explicitly a reference cycle
#
# ConnectionRefusedError: [Errno 111] Connection refused
#
# ...

# %% [markdown]
# **9. Implement a basic RAG (Retrieval-Augmented Generation) system using Ollama with Llama3.**
#
# Answer:
#
# Python Code

# %%
import chromadb
import requests

client = chromadb.Client()
collection = client.create_collection("knowledge")

docs = [
    "AI is used in healthcare for diagnosis",
    "Machine learning helps detect diseases",
    "Deep learning improves medical imaging"
]

collection.add(documents=docs, ids=["1","2","3"])

query = "How is AI used in healthcare?"

results = collection.query(query_texts=[query], n_results=2)

context = " ".join(results["documents"][0])

prompt = f"""
Context: {context}
Question: {query}
Answer:
"""

response = requests.post(
    "http://localhost:11434/api/generate",
    json={
        "model":"llama3",
        "prompt":prompt,
        "stream":False
    }
)

print(response.json()["response"])
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /tmp/ipykernel_586/2300736823.py in <cell line: 0>()
# ----> 1 import chromadb
#       2 import requests
#       3
#       4 client = chromadb.Client()
#       5 collection = client.create_collection("knowledge")
#
# ModuleNotFoundError: No module named 'chromadb'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %% [markdown]
# **10: Health-tech chatbot solution using Hugging Face, VectorDB, and Ollama.**
#
# Answer:
#
# **Proposed Architecture**
#
# The chatbot system consists of three components:
#
# 1. **Hugging Face Models**
#
# Used to generate embeddings and understand medical queries.
#
# 2.** Vector Database (ChromaDB)**
#
# Stores embeddings of medical research articles.
#
# 3. **Ollama (Llama3)**
#
# Generates final answers using retrieved context.
#
# **Workflow**
#
# 1. Research articles are converted into embeddings.
#
# 2. Embeddings are stored in ChromaDB.
#
# 3. User query is converted into embedding.
#
# 4. Similar documents are retrieved.
#
# 5. Retrieved context is passed to Llama3.
#
# 6. Llama3 generates the final response.

# %%
from sentence_transformers import SentenceTransformer
import chromadb
import requests

model = SentenceTransformer('all-MiniLM-L6-v2')

client = chromadb.Client()
collection = client.create_collection("medical_docs")

docs = [
    "COVID-19 vaccines help prevent severe infection",
    "Regular exercise reduces heart disease risk",
    "Diabetes can be managed through diet and medication"
]

embeddings = model.encode(docs).tolist()

collection.add(
    documents=docs,
    embeddings=embeddings,
    ids=["1","2","3"]
)

query = "How can diabetes be controlled?"

query_embedding = model.encode([query]).tolist()

results = collection.query(
    query_embeddings=query_embedding,
    n_results=2
)

context = " ".join(results["documents"][0])

prompt = f"""
Context: {context}
Question: {query}
Provide a helpful medical explanation.
"""

response = requests.post(
    "http://localhost:11434/api/generate",
    json={
        "model":"llama3",
        "prompt":prompt,
        "stream":False
    }
)

print(response.json()["response"])
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /tmp/ipykernel_586/2623389875.py in <cell line: 0>()
#       1 from sentence_transformers import SentenceTransformer
# ----> 2 import chromadb
#       3 import requests
#       4
#       5 model = SentenceTransformer('all-MiniLM-L6-v2')
#
# ModuleNotFoundError: No module named 'chromadb'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------
